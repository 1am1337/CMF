# %% [markdown]
# ## CMF 1
# Institut für Musikinformatik und Musikwissenschaft – Wintersemester 2025–26
# ### Woche 10 – Übungen

# %% [markdown]
# ### Aufgabe 00.
#
# Überlege dir eine Frage zum Inhalt der Vorlesung, z. B. über einen Punkt, der unklar geblieben ist oder über etwas, worüber du gerne mehr wissen möchtest.

# %% [markdown]
# ### Aufgabe 01.
#
# Überlege dir ein Thema, zu dem du gerne eine Projektarbeit machen möchtest.

# %% [markdown]
# ### Aufgabe 02.
#
# Verschaffe dir einen Überblick über die Inhalte der ersten 10 CMF-Wochen.

# %% [markdown]
# ### Aufgabe 03.
#
# Analysiere die Form des Songs *Bohemian Rhapsody* mithilfe einer Selbstähnlichkeitsanalyse des Songs.
#
# *Hinweis:* Wähle beim Erstellen eines Chromagramms "hohe" Werte für *n_fft* und *hop_length* (z. B. *n_fft* = 4096
# und *hop_length* = 2048), um lange Rechenzeiten zu vermeiden.
